# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df= pd.read_csv("D:\\Profile\\Desktop\\Power BI Data\\survey_results_public.csv")
schema_df = pd.read_csv("D:\\Profile\\Desktop\\Power BI Data\\survey_results_schema.csv")

# %% [markdown]
# # Finding individuals' coding reason

# %%
reasons = df['MainBranch'].value_counts()
reasons
# Out:
# I am a developer by profession                                                   65679
# I am a student who is learning to code                                           10189
# I am not primarily a developer, but I write code sometimes as part of my work     7539
# I code primarily as a hobby                                                       3340
# I used to be a developer by profession, but no longer am                          1584
# Name: MainBranch, dtype: int64

# %%
labels = ['I am a developer by profession','I am a student who is learning to code','I am not primarily a developer, but I write code sometimes as part of my work','I code primarily as a hobby','I used to be a developer by profession, but no longer am']
plt.pie(reasons,startangle=50, autopct='%.1f%%',labels = labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x1dd67bd5348>,
# ...
#  [Text(-1.0975304690001768, -0.07366729000209216, 'I am a developer by profession'),
#   Text(1.0230578471743716, -0.4041690751838147, 'I am a student who is learning to code'),
#   Text(1.0646301958343674, 0.2766993786000919, 'I am not primarily a developer, but I write code sometimes as part of my work'),
#   Text(0.8815162881385602, 0.6579734293620184, 'I code primarily as a hobby'),
#   Text(0.753391636116333, 0.8014992468056069, 'I used to be a developer by profession, but no longer am')],
#  [Text(-0.5986529830910055, -0.04018215818295936, '74.4%'),
#   Text(0.5580315530042027, -0.2204558591911716, '11.5%'),
#   Text(0.5807073795460185, 0.1509269337818683, '8.5%'),
#   Text(0.4808270662573964, 0.35889459783382816, '3.8%'),
#   Text(0.41094089242709064, 0.4371814073485128, '1.8%')])

# %% [markdown]
# # 5 countries with a majority of respondents

# %%
countries = ['United States','India','Germany','United Kingdom','Canada']
filt = df['Country'].isin(countries)

# %%
countrynum=df.loc[filt,'Country']
totalcountrynum= countrynum.value_counts()
totalcountrynum
# Out:
# United States     20949
# India              9061
# Germany            5866
# United Kingdom     5737
# Canada             3395
# Name: Country, dtype: int64

# %%
plt.pie(totalcountrynum,labels = countries, autopct = "%1.f%%", startangle = 90)
# Out:
# ([<matplotlib.patches.Wedge at 0x1dd685ce208>,
# ...
#  [Text(-1.0935268238613474, 0.11915991564160286, 'United States'),
#   Text(0.4438957679707252, -1.0064574244237459, 'India'),
#   Text(1.0929228586956585, -0.12457778670577596, 'Germany'),
#   Text(0.8438705084889466, 0.705607939937333, 'United Kingdom'),
#   Text(0.25823805454191173, 1.0692582041707273, 'Canada')],
#  [Text(-0.5964691766516439, 0.06499631762269246, '47%'),
#   Text(0.24212496434766828, -0.5489767769584067, '20%'),
#   Text(0.5961397411067227, -0.06795152002133234, '13%'),
#   Text(0.46029300463033446, 0.3848770581476361, '13%'),
#   Text(0.14085712065922457, 0.5832317477294876, '8%')])

# %% [markdown]
# # investigating more about the countries

# %% [markdown]
# # United States

# %%
country_grp = df.groupby(['Country'])
social_media=country_grp['SocialMedia'].value_counts().loc['United States']
labels = ['Reddit ',"Twitter","Facebook","YouTube","I don't use social media","Instagram","LinkedIn","WhatsApp","Snapchat","WeChat 微信","VK ВКонта́кте ","Weibo 新浪微博","Hello","Youku Tudou 优酷"]

# %%
plt.pie(social_media, autopct = '%1.f%%', labels=['Reddit ',"Twitter","Facebook","YouTube","I don't use social media","Instagram","LinkedIn","WhatsApp","Snapchat","WeChat 微信","VK ВКонта́кте ","Weibo 新浪微博","Hello","Youku Tudou 优酷"], startangle = 90)
# Out:
# ([<matplotlib.patches.Wedge at 0x1dd68645c08>,
# ...
#  [Text(-0.8570585809701866, 0.6895292515806491, 'Reddit '),
#   Text(-0.7978464935597497, -0.7572588544972007, 'Twitter'),
#   Text(0.19446410268330042, -1.0826743336606715, 'Facebook'),
#   Text(0.9311803867162369, -0.5855792750729824, 'YouTube'),
#   Text(1.092769753537088, 0.12591372345575463, "I don't use social media"),
#   Text(0.8664862260097872, 0.6776441692623911, 'Instagram'),
#   Text(0.5160736421985672, 0.9714257541510342, 'LinkedIn'),
#   Text(0.25403153709226284, 1.0702653774473612, 'WhatsApp'),
#   Text(0.09504119936705839, 1.095886476977826, 'Snapchat'),
#   Text(0.022926317250140216, 1.0997610576745052, 'WeChat 微信'),
#   Text(0.005344065040763199, 1.0999870185456009, 'VK ВКонта́кте '),
#   Text(0.0024134354342031108, 1.0999973524192708, 'Weibo 新浪微博'),
#   Text(0.000689526351814494, 1.0999997838878925, 'Hello'),
#   Text(0.00017235310420796, 1.099999986497458, 'Youku Tudou 优酷')],
# ...

# %%
salary_mean= country_grp['ConvertedComp'].mean().loc['United States']
salary_mean
# Out:
# 249546.25458914627

# %%
salary_median = country_grp['ConvertedComp'].median().loc['United States']
salary_median
# Out:
# 110000.0

# %%
hobbyist = country_grp['Hobbyist'].value_counts().loc['United States']

# %%
plt.pie(hobbyist, autopct = "%1.f%%", startangle = 90, labels=["Hobbyist","Not Hobbyist"])
# Out:
# ([<matplotlib.patches.Wedge at 0x1dd686f7dc8>,
# ...
#  [Text(-0.635868046901591, -0.8975922386749766, 'Hobbyist'),
#   Text(0.6358681309402388, 0.8975921791407094, 'Not Hobbyist')],
#  [Text(-0.3468371164917769, -0.4895957665499872, '80%'),
#   Text(0.3468371623310393, 0.48959573407675056, '20%')])

# %% [markdown]
# # India

# %%
social_media=country_grp['SocialMedia'].value_counts().loc['India']
labels = ['Reddit ',"Twitter","Facebook","YouTube","I don't use social media","Instagram","LinkedIn","WhatsApp","Snapchat","WeChat 微信","VK ВКонта́кте ","Weibo 新浪微博","Hello","Youku Tudou 优酷"]
plt.pie(social_media, autopct = '%1.f%%', labels=labels, startangle = 90)
# Out:
# ([<matplotlib.patches.Wedge at 0x1dd68744ec8>,
# ...
#  [Text(-0.9678717881028867, 0.52270852470045, 'Reddit '),
#   Text(-0.3623063420065073, -1.0386212565424722, 'Twitter'),
#   Text(0.6767181723328952, -0.8672096143576973, 'Facebook'),
#   Text(1.062441546498664, -0.2849876493350669, 'YouTube'),
#   Text(1.0384256153658642, 0.3628666991500138, "I don't use social media"),
#   Text(0.7449101445627494, 0.8093879641602685, 'Instagram'),
#   Text(0.4067907059063184, 1.0220182589309446, 'LinkedIn'),
#   Text(0.13027845120454204, 1.0922579938603085, 'WhatsApp'),
#   Text(0.022554028075612693, 1.099768755610726, 'Snapchat'),
#   Text(0.011475467837224702, 1.0999401409340042, 'WeChat 微信'),
#   Text(0.00751849873231226, 1.0999743052348143, 'VK ВКонта́кте '),
#   Text(0.0039571418686276975, 1.0999928822625316, 'Weibo 新浪微博'),
#   Text(0.0015828785938581706, 1.0999988611336637, 'Hello'),
#   Text(0.0003957434997688151, 1.099999928812308, 'Youku Tudou 优酷')],
# ...

# %%
salary_mean= country_grp['ConvertedComp'].mean().loc['India']
salary_mean
# Out:
# 28057.664916229056

# %%
salary_median = country_grp['ConvertedComp'].median().loc['India']
salary_median
# Out:
# 10080.0

# %%
hobbyist = country_grp['Hobbyist'].value_counts().loc['India']
plt.pie(hobbyist, autopct = "%1.f%%", startangle = 90, labels=["Hobbyist","Not Hobbyist"])
# Out:
# ([<matplotlib.patches.Wedge at 0x1dd687d7d48>,
# ...
#  [Text(-0.6633545271934268, -0.8774740858008203, 'Hobbyist'),
#   Text(0.6633545271934269, 0.8774740858008202, 'Not Hobbyist')],
#  [Text(-0.3618297421055055, -0.4786222286186292, '79%'),
#   Text(0.36182974210550556, 0.47862222861862913, '21%')])

# %%
country_use_python=country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())

# %%
country_respondents = df['Country'].value_counts()
country_respondents
# Out:
# United States                       20949
# India                                9061
# Germany                              5866
# United Kingdom                       5737
# Canada                               3395
#                                     ...
# Chad                                    1
# Sao Tome and Principe                   1
# Saint Vincent and the Grenadines        1
# Timor-Leste                             1
# Niger                                   1
# Name: Country, Length: 179, dtype: int64

# %% [markdown]
# # Finding python usage in the countries

# %%
final_python=pd.concat([country_use_python,country_respondents],axis='columns', sort = False)

# %%
final_python.head(50)
# Out:
#                                        LanguageWorkedWith  Country
# Afghanistan                                             8       44
# Albania                                                23       86
# Algeria                                                40      134
# Andorra                                                 0        7
# Angola                                                  2        5
# Antigua and Barbuda                                     0        9
# Argentina                                             191      553
# Armenia                                                28       86
# Australia                                             790     1903
# Austria                                               338      839
# Azerbaijan                                             17       49
# Bahamas                                                 2        3
# Bahrain                                                 4       18
# ...

# %%
final_python['pctg of python usage'] = (final_python['LanguageWorkedWith']/final_python['Country'])*100

# %%
final_python
# Out:
#                                       LanguageWorkedWith  Country  \
# Afghanistan                                            8       44
# Albania                                               23       86
# Algeria                                               40      134
# Andorra                                                0        7
# Angola                                                 2        5
# ...                                                  ...      ...
# Venezuela, Bolivarian Republic of...                  28       88
# Viet Nam                                              78      231
# Yemen                                                  3       19
# Zambia                                                 4       12
# Zimbabwe                                              14       39
#
#                                       pctg of python usage
# Afghanistan                                      18.181818
# ...

# %%
final_python.sort_values(by='pctg of python usage', ascending = False, inplace= True)

# %%
numus1= final_python.loc['United States']['pctg of python usage']
numus=np.array((numus1,numger,numind,numuk,numcan))

# %%
numger= final_python.loc['Germany']['pctg of python usage']

# %%
numind=final_python.loc['India']['pctg of python usage']
labels= np.array(["United States","Germany","India","United Kingdom","Canada"])
numuk = final_python.loc['United Kingdom']['pctg of python usage']
numcan=final_python.loc['Canada']['pctg of python usage']

# %%
plt.bar(labels,numus, width =0.6, color = 'b')
plt.title("Python Usage % by country")
plt.xlabel("Countries")
plt.ylabel("Python pctg")
# Out:
# Text(0, 0.5, 'Python pctg')

# %% [markdown]
# # Looking for correlation between the data

# %%
df.corr()
# Out:
#                Respondent  CompTotal  ConvertedComp  WorkWeekHrs  CodeRevHrs  \
# Respondent       1.000000  -0.003357       0.002930    -0.004589   -0.005240
# CompTotal       -0.003357   1.000000       0.039725     0.003074    0.061090
# ConvertedComp    0.002930   0.039725       1.000000     0.013908   -0.021261
# WorkWeekHrs     -0.004589   0.003074       0.013908     1.000000    0.021092
# CodeRevHrs      -0.005240   0.061090      -0.021261     0.021092    1.000000
# Age             -0.001829   0.016500       0.108268     0.019976   -0.022486
#
#                     Age
# Respondent    -0.001829
# CompTotal      0.016500
# ConvertedComp  0.108268
# WorkWeekHrs    0.019976
# CodeRevHrs    -0.022486
# Age            1.000000

# %% [markdown]
# # Investigating the work hours and organization have an impact for salary or not

# %%
import seaborn as sns
df=pd.read_csv("D:\\Profile\\Desktop\\Power BI Data\\survey_results_public.csv")
df2= df[['ConvertedComp','WorkWeekHrs']]

sns.pairplot(df2, kind="scatter")
plt.show()

# %%
plt.scatter(df['WorkWeekHrs'], df['ConvertedComp'])

# %%
salary=df['ConvertedComp'].dropna()
salary = salary.head(55823)

# %%
workhrs=df['WorkWeekHrs'].dropna()
workhrs = workhrs.head(55823)

# %%
np.corrcoef(workhrs,salary)
# Out:
# array([[1.        , 0.00129267],
#        [0.00129267, 1.        ]])

# %%
from scipy.stats import linregress
linregress(workhrs,salary)
# Out:
# LinregressResult(slope=9.347941740509993, intercept=126716.05847573116, rvalue=0.0012926710035638205, pvalue=0.7600529443400391, stderr=30.60756785396288)

# %%
df= pd.read_csv("D:\\Profile\\Desktop\\Power BI Data\\survey_results_public.csv")
years_code = df['YearsCode'].dropna()

# %%
workhrs = df['WorkWeekHrs'].dropna()

# %%
org_size = df['OrgSize'].dropna()
org_size.value_counts()
# Out:
# 20 to 99 employees                                    15199
# 100 to 499 employees                                  12834
# 10,000 or more employees                              10147
# 1,000 to 4,999 employees                               7520
# 2-9 employees                                          7393
# 10 to 19 employees                                     6768
# 500 to 999 employees                                   4575
# Just me - I am a freelancer, sole proprietor, etc.     4370
# 5,000 to 9,999 employees                               2985
# Name: OrgSize, dtype: int64

# %%
df_org = df.loc[(df['OrgSize'] == "5,000 to 9,999 employees")]

# %%
new_df = df.loc[df['OrgSize'] == "10,000 or more employees"]
a= df.loc[df['OrgSize'] == "1,000 to 4,999 employees"]
b= df.loc[df['OrgSize'] == "500 to 999 employees"]
frames = [df_org, new_df,a,b]
final_df = pd.concat(frames)

# %%
org_size = final_df['OrgSize'].dropna().head(19703)
org_size.value_counts()
# Out:
# 10,000 or more employees    10147
# 1,000 to 4,999 employees     6571
# 5,000 to 9,999 employees     2985
# Name: OrgSize, dtype: int64

# %%
sal = final_df['ConvertedComp'].dropna().head(19703)
final_df
# Out:
#        Respondent                      MainBranch Hobbyist  \
# 101           102  I am a developer by profession       No
# 105           106  I am a developer by profession      Yes
# 130           131  I am a developer by profession      Yes
# 149           151  I am a developer by profession      Yes
# 162           164  I am a developer by profession      Yes
# ...           ...                             ...      ...
# 88794       73695                             NaN      Yes
# 88825       79795                             NaN      Yes
# 88833       81093                             NaN      Yes
# 88850       83786                             NaN       No
# 88872       87739                             NaN      Yes
#
#                                              OpenSourcer  \
# 101                                                Never
# 105                              Less than once per year
# 130                           Once a month or more often
# ...

# %%
workhrs = final_df['WorkWeekHrs'].dropna().head(19703)
workhrs.count()
# Out:
# 19703

# %%
from statsmodels.formula.api import ols

# %%
data = df
sal2 =final_df['ConvertedComp'].dropna()
data = pd.DataFrame({'Salary':sal2,'Workhrs':workhrs,'Organization_Size':org_size})

# %%
sal2 =list(data['Salary'].dropna().head(19703))
worj2=list(data['Workhrs'].dropna().head(19703))
ogr = list(org_size.dropna().head(19703))
df = pd.DataFrame({'sal':sal2, 'hrs':worj2, 'ogr': ogr})

# %%
from statsmodels.formula.api import ols
model = ols("sal ~ hrs",df).fit()
print(model.summary())
sns.regplot(x='hrs', y='sal', data=df)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    sal   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     2.470
# Date:                Sat, 22 Aug 2020   Prob (F-statistic):              0.116
# Time:                        22:23:30   Log-Likelihood:            -2.7761e+05
# No. Observations:               19703   AIC:                         5.552e+05
# Df Residuals:                   19701   BIC:                         5.552e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.517e+05   3088.643     49.122      0.000    1.46e+05    1.58e+05
# ...
